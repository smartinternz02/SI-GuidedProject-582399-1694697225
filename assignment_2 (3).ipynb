# %% [markdown]
# NAME : CH DEVAK REDDY
#
# REG NO: 21BCE2940
#
# EMAIL: devakreddy.chilaka2021@vitstudent.ac.in
#
# SLOT: Morning(10-12 AM)

# %% [markdown]
# # Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %% [markdown]
# #printdataset

# %%
data = sns.load_dataset('car_crashes')

# %%
data
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
data.shape
# Out:
# (51, 8)

# %%
data.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
data.tail()
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 46   12.7     2.413    3.429          11.049       11.176       768.95
# 47   10.6     4.452    3.498           8.692        9.116       890.03
# 48   23.8     8.092    6.664          23.086       20.706       992.61
# 49   13.8     4.968    4.554           5.382       11.592       670.31
# 50   17.4     7.308    5.568          14.094       15.660       791.14
#
#     ins_losses abbrev
# 46      153.72     VA
# 47      111.62     WA
# 48      152.56     WV
# 49      106.62     WI
# 50      122.04     WY

# %%
data.describe()
# Out:
#            total   speeding    alcohol  not_distracted  no_previous  \
# count  51.000000  51.000000  51.000000       51.000000    51.000000
# mean   15.790196   4.998196   4.886784       13.573176    14.004882
# std     4.122002   2.017747   1.729133        4.508977     3.764672
# min     5.900000   1.792000   1.593000        1.760000     5.900000
# 25%    12.750000   3.766500   3.894000       10.478000    11.348000
# 50%    15.600000   4.608000   4.554000       13.857000    13.775000
# 75%    18.500000   6.439000   5.604000       16.140000    16.755000
# max    23.900000   9.450000  10.038000       23.661000    21.280000
#
#        ins_premium  ins_losses
# count    51.000000   51.000000
# mean    886.957647  134.493137
# std     178.296285   24.835922
# min     641.960000   82.750000
# 25%     768.430000  114.645000
# 50%     858.970000  136.050000
# 75%    1007.945000  151.870000
# max    1301.520000  194.780000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %% [markdown]
# # Handling the null values:

# %%
data.isnull().any()
# There are no null values in the dataset.
# Out:
# total             False
# speeding          False
# alcohol           False
# not_distracted    False
# no_previous       False
# ins_premium       False
# ins_losses        False
# abbrev            False
# dtype: bool

# %%
data.isnull().sum()
# There are no null values in the dataset.
# Out:
# total             0
# speeding          0
# alcohol           0
# not_distracted    0
# no_previous       0
# ins_premium       0
# ins_losses        0
# abbrev            0
# dtype: int64

# %% [markdown]
# # Seperating the dependent and independent variables:

# %%
data.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
x=data.iloc[:,0:7]
y=data.iloc[:,7:8]

# %%
x
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
y
# Out:
#    abbrev
# 0      AL
# 1      AK
# 2      AZ
# 3      AR
# 4      CA
# 5      CO
# 6      CT
# 7      DE
# 8      DC
# 9      FL
# 10     GA
# 11     HI
# 12     ID
# 13     IL
# 14     IN
# 15     IA
# 16     KS
# 17     KY
# 18     LA
# 19     ME
# 20     MD
# 21     MA
# 22     MI
# 23     MN
# 24     MS
# 25     MO
# 26     MT
# 27     NE
# 28     NV
# 29     NH
# 30     NJ
# 31     NM
# 32     NY
# 33     NC
# 34     ND
# 35     OH
# 36     OK
# 37     OR
# 38     PA
# 39     RI
# 40     SC
# 41     SD
# 42     TN
# 43     TX
# 44     UT
# 45     VT
# 46     VA
# 47     WA
# 48     WV
# 49     WI
# 50     WY

# %% [markdown]
# # Splitting into training and testing set

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((35, 7), (16, 7), (35, 1), (16, 1))

# %% [markdown]
# # Feature scaling:

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
x_train
# Out:
# array([[-0.2683591 , -0.64144528, -0.30694959,  0.14952247, -0.04313625,
#         -1.05308601, -1.15832768],
#        [-0.67971246, -1.23868209, -0.80627582, -0.41457159, -0.69592102,
#         -0.72287406,  0.62744695],
#        [ 1.10281878,  1.10788695,  1.34031221,  0.39577043,  1.54298756,
#          2.17106755,  2.26414129],
#        [ 1.85696662,  1.55975671,  1.27532259,  2.07625754,  1.69770684,
#          0.53982391,  0.58120814],
#        [ 0.87428914, -0.40984355,  0.62606979,  0.60787476,  0.46422243,
#         -0.7287455 ,  0.70118987],
#        [ 0.00587648, -1.11253306, -0.48711885,  0.45040023, -0.0722717 ,
#         -1.3997267 , -0.9370989 ],
#        [ 0.62290652, -0.70501257,  0.18401164, -0.14990677,  1.0260845 ,
#         -0.15323164, -0.68677157],
#        [-1.02250694, -1.54469204, -0.99481008, -0.7077929 , -1.30877012,
#          2.28381045,  0.87179513],
#        [ 0.48578874, -0.05948434, -0.26383766,  0.13524423,  0.29719593,
# ...

# %%
x_test
# Out:
# array([[-1.33274423, -0.5706937 , -0.95548614, -1.42195376, -1.45436493,
#         -0.68387903, -0.3083689 ],
#        [ 0.43675022,  2.23959723,  0.94808052, -0.1115058 ,  0.35291028,
#         -0.02209856, -0.27548239],
#        [-0.13308698, -1.14213691, -0.7391132 ,  0.03314205,  0.12139048,
#          0.27790782,  0.73797784],
#        [-0.58295845, -0.9231532 , -0.71438487, -0.40541792, -1.05751997,
#          1.41778197,  1.17615579],
#        [ 0.76665597,  0.70671126, -0.06526606,  0.2805822 ,  1.20246202,
#          0.19893751, -0.76507446],
#        [-0.40300986,  0.14830281, -0.32491358, -0.22999393,  0.13592101,
#          0.95169548,  0.54853303],
#        [-0.73291561, -0.56026591, -0.64638195, -0.50974902, -0.39137583,
#         -0.85902226, -0.79935054],
#        [-1.12280421, -0.63534604, -0.91066603, -1.19667243, -1.38590998,
#          2.13186296,  1.07193799],
#        [ 1.60641604,  1.66398291,  2.10258468,  1.00443698,  1.31031085,
# ...

# %% [markdown]
# #SCATTER PLOT

# %%
sns.scatterplot(x="ins_premium", y="alcohol", data=data)
# Out:
# <Axes: xlabel='ins_premium', ylabel='alcohol'>

# %% [markdown]
# Inference: This scatterplot can help explore the relationship between insurance premiums and alcohol-related accidents.

# %%
sns.scatterplot(x="speeding",y="alcohol",data=data)
# Out:
# <Axes: xlabel='speeding', ylabel='alcohol'>

# %% [markdown]
# This code creates a scatterplot showing the relationship between "speeding" and "alcohol" variables in the provided dataset "data."

# %%
sns.scatterplot(x="no_previous",y="not_distracted",data=data)
# Out:
# <Axes: xlabel='no_previous', ylabel='not_distracted'>

# %% [markdown]
#  INFERENCE: DIRECTLY PROPORTIONAL
#        As the number of drivers with no previous accidents increases, there seems to be a tendency for more not distracted drivers,
#        implying a potential direct or positive correlation.

# %% [markdown]
# # line plot

# %% [markdown]
#   Inference: DIRECTLY PROPORTIONAL
#      The percentage of accidents involving alcohol could be a significant factor in accident rates.
#      In this graph we can observe that,as the alcohol rate increases the car_crashes also increases.

# %%
sns.lineplot(x="total",y="ins_losses",data=data,errorbar=None,color="green")
# Out:
# <Axes: xlabel='total', ylabel='ins_losses'>

# %% [markdown]
# Inference:This line of code is creating a scatter plot using the Seaborn library (sns.scatterplot).

# %%
sns.scatterplot(x="ins_losses", y="ins_premium", data=data)
plt.xlabel("Insurance Losses")
plt.ylabel("Insurance Premium")
plt.title("Scatterplot of Insurance Losses vs. Insurance Premium")
plt.show()

# %% [markdown]
#  INFERENCE: CORRELATION EXSISTS
#  As alcohol consumption increases, speeding tends to increase as well, indicating a positive or direct correlation between the two variables.

# %%
selected_columns = data[['total', 'ins_losses', 'alcohol', 'speeding']]
pd.plotting.scatter_matrix(selected_columns, figsize=(8, 8),color="green")
plt.suptitle("Scatterplot Matrix of Selected Columns")
plt.show()

# %% [markdown]
#   # Inference:
#   This matrix displays scatterplots of selected columns, allowing you to explore relationships between them.

# %%
sns.lineplot(x="ins_losses", y="speeding", data=data, ci=None)
# Out:
# <ipython-input-111-8bb8330cdd8a>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x="ins_losses", y="speeding", data=data, ci=None)
# <Axes: xlabel='ins_losses', ylabel='speeding'>

# %% [markdown]
# Inference: This lineplot shows the relationship between insurance losses and speeding-related accidents without confidence intervals.

# %% [markdown]
# # pair plot

# %%
sns.pairplot(data=data[['total', 'speeding', 'alcohol']], diag_kind='kde')
plt.suptitle('Pairplot of Numeric Variables')
plt.show()

# %% [markdown]
# # pie chart

# %%
cc = data[['alcohol', 'speeding', 'not_distracted', 'no_previous']].sum()
labels = cc.index
plt.figure(figsize=(8, 8))
plt.pie(cc, labels=labels, autopct='%1.1f%%')
plt.title('Distribution of Factors')
plt.show()

# %% [markdown]
# # DISTINCT PLOT

# %%
sns.distplot(data['total'])
plt.show()
# Out:
# <ipython-input-89-a41dec2774df>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['total'])

# %% [markdown]
#  #INFERENCE:
#   The distribution plot of the "total" variable indicates that it is right-skewed, with a majority of data points clustered towards lower values.
# This suggests that most states have a relatively lower number of total accidents. However, there are some outliers on the righttail, representing states with higher accident rates.

# %%
sns.distplot(data["speeding"])
plt.show()
# Out:
# <ipython-input-90-e8cfd3b812dc>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["speeding"])

# %% [markdown]
#   INFERENCE:
# This plot illustrates the distribution of speeding-related accidents in the dataset.
# The distribution of "speeding" incidents is right-skewed, with a majority of regions having lower speeding rates.

# %%
sns.relplot(x="total", y="speeding", data=data, hue="no_previous")

# %% [markdown]
# #multi variate

# %%
#multi  variate
sns.relplot(x="speeding",y="total",data=data,hue="alcohol")

# %% [markdown]
#  Inference: As the speeding increases the rate of total crashes also increases, but there is a drasting increase in the creashes if there is a high alcohol rate along with speeding.

# %% [markdown]
# #RELATION PLOT

# %%
sns.relplot(x="alcohol", y="speeding", hue="ins_premium", data=data)
plt.title("Relationship between Alcohol and Speeding with Insurance Premium")
plt.xlabel("Alcohol Involvement (%)")
plt.ylabel("Speeding Incidents")
plt.show()

# %% [markdown]
#  INFERENCE:
#  The relational plot illustrates a potential association between higher alcohol involvement and increased speeding incidents.Variations in insurance premium costs suggest that regions with elevated alcohol involvement may face diverse insurance pricing.

# %% [markdown]
# #bar plot

# %%
sns.countplot(data=data, x='abbrev')
plt.title('Number of Data Points by State Abbreviation')
plt.xticks(rotation=45)
plt.show()

# %%
plt.subplots(figsize=(20,8))
sns.barplot(data=data,x="not_distracted",y="alcohol",ci=None)
plt.show()
# Out:
# <ipython-input-94-916bcd1decc8>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=data,x="not_distracted",y="alcohol",ci=None)

# %% [markdown]
#  INFERENCE: INVERSLY PROPORTIONAL
# Higher alcohol involvement tend to have fewer incidents of being not distracted.

# %% [markdown]
# # box plot

# %%
plt.subplots(figsize=(20,8))
sns.boxplot(x="total", y="no_previous", data=data)
plt.xlabel("Total Accidents")
plt.ylabel("Percentage of Drivers with No Previous Accidents")
plt.title("Boxplot of Total Accidents vs. No Previous Accidents")
plt.show()

# %% [markdown]
#   INFERENCE:
# The boxplot illustrates a negative relationship between "Total Accidents" and the "Percentage of Drivers with No Previous Accidents."
#  As the total number of accidents increases, there is a tendency for the percentage of drivers with no previous accidents to decrease.
#  This indicates an inverse proportionality between these variables, where higher accident rates are associated with a lower percentage
#    of inexperienced drivers.

# %%
plt.subplots(figsize=(20,5))
sns.boxplot(x="alcohol", y="no_previous", data=data)
# Out:
# <Axes: xlabel='alcohol', ylabel='no_previous'>

# %% [markdown]
# INFERENCE: INVERSLY PROPORTIONAL
# The boxplot between "alcohol" and "no_previous" in the car_crashes dataset shows a notable pattern.
# As alcohol involvement increases, the number of drivers with no previous accidents tends to decrease

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x="no_previous", y="total", data=data)
plt.xlabel("Distracted Driving")
plt.ylabel("Total Accidents")
plt.title("Box Plot of Total Accidents by Distracted Driving Status")
plt.show()

# %% [markdown]
# # joint plot

# %%
sns.jointplot(x="alcohol", y="ins_losses", data=data)

# %% [markdown]
# # Swarm Plot.

# %%
plt.figure(figsize=(12, 6))
sns.swarmplot(data=data, x='abbrev', y='total')
plt.title('Distribution of total accidents by State')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # correlation

# %%
cor=data.corr()
cor
# Out:
# <ipython-input-99-42f3d3de063e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor=data.corr()
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# ...

# %% [markdown]
#  INFERENCE:
# The sns.heatmap for the "car_crashes" table indicates the correlation between variables. The "YlGnBu" color map helps
# visualize the strength of these correlations, with darker shades representing stronger positive correlations, while annotated values provide precise correlation coefficients.
#   we observe high/positive relation between total and alcohol,no_previous,not_distracted,speeding.

# %% [markdown]
# #HISTOGRAM

# %%
plt.hist(data['total'], bins=10, edgecolor='k')
plt.title('Histogram of Total Accidents')
plt.xlabel('Total Accidents')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# The histogram of "Total Accidents" shows that the majority of states have a relatively low number of accidents, with a peak around 15-17 accidents.
#  A few states exhibit higher accident rates as indicated by the right tail of the distribution.
# This distribution provides insights into the variation in accident frequencies among states

# %%
plt.hist(x="alcohol")
plt.show()

# %% [markdown]
# # heat map

# %%
sns.heatmap(cor,annot=True)
# Out:
# <Axes: >
